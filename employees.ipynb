# %%
import sqlite3

# %%
con = sqlite3.connect("employees.db")

# %%
cur = con.cursor()
cur.execute("CREATE TABLE employees(first_name, last_name, dob, job_title)")

# %%
res = cur.execute("SELECT name FROM sqlite_master")
res.fetchone()
# Out:
# ('employees',)

# %%
cur.execute("""
            INSERT INTO employees VALUES
            ('Alice', 'Johnson', '1990-04-12', 'Software Engineer'),
            ('Mark', 'Thompson', '1985-11-23', 'HR Manager'),
            ('Sophie', 'Lee', '1993-02-17', 'Data Analyst'),
            ('David', 'Brown', '1991-06-05', 'Marketing Specialist'),
            ('Olivia', 'Miller', '1988-09-14', 'Project Manager'),
            ('Liam', 'Garcia', '1995-02-10', 'Customer Support Rep'),
            ('Noah', 'Martinez', '1990-07-18', 'Data Scientist'),
            ('Emma', 'Rodriguez', '1996-11-04', 'UX Designer'),
            ('William', 'Davis', '1987-03-22', 'Software Engineer'),
            ('Ava', 'Lopez', '1992-08-29', 'Recruiter'),
            ('Ethan', 'Wilson', '1991-12-02', 'Systems Administrator'),
            ('Mia', 'Anderson', '1989-10-07', 'HR Coordinator'),
            ('James', 'Taylor', '1984-05-17', 'Finance Analyst'),
            ('Charlotte', 'Thomas', '1994-03-25', 'Marketing Associate'),
            ('Benjamin', 'Hernandez', '1993-09-11', 'DevOps Engineer'),
            ('Amelia', 'Moore', '1990-01-20', 'Software Engineer'),
            ('Lucas', 'Martin', '1986-06-09', 'Senior Developer'),
            ('Harper', 'Jackson', '1995-10-30', 'Graphic Designer'),
            ('Henry', 'White', '1989-07-01', 'Operations Manager'),
            ('Evelyn', 'Harris', '1992-02-26', 'Data Engineer'),
            ('Alexander', 'Clark', '1988-08-18', 'Network Engineer'),
            ('Ella', 'Lewis', '1997-04-02', 'Intern'),
            ('Michael', 'Walker', '1983-09-05', 'Chief Technical Officer'),
            ('Abigail', 'Hall', '1990-12-09', 'Product Manager'),
            ('Daniel', 'Allen', '1991-05-19', 'Software Tester'),
            ('Grace', 'Young', '1994-11-13', 'Marketing Intern'),
            ('Sebastian', 'King', '1989-06-21', 'Security Analyst'),
            ('Emily', 'Wright', '1995-07-16', 'Web Developer'),
            ('Jacob', 'Scott', '1987-12-28', 'Technical Writer'),
            ('Scarlett', 'Green', '1992-01-04', 'Recruitment Specialist'),
            ('Matthew', 'Adams', '1985-03-15', 'Chief Financial Officer'),
            ('Victoria', 'Baker', '1991-09-23', 'HR Generalist'),
            ('Elijah', 'Nelson', '1993-07-14', 'Cloud Architect'),
            ('Sofia', 'Carter', '1990-10-02', 'Digital Marketing Manager'),
            ('Jackson', 'Mitchell', '1988-12-19', 'Business Analyst'),
            ('Chloe', 'Perez', '1994-06-30', 'UI Designer'),
            ('Aiden', 'Roberts', '1996-09-12', 'Junior Developer'),
            ('Lily', 'Turner', '1987-02-28', 'Training Coordinator'),
            ('Logan', 'Phillips', '1989-04-17', 'Software Engineer'),
            ('Zoe', 'Campbell', '1998-05-24', 'Data Intern'),
            ('Nathan', 'Parker', '1986-10-09', 'Operations Analyst'),
            ('Hannah', 'Evans', '1993-01-29', 'Administrative Assistant'),
            ('Samuel', 'Edwards', '1992-03-03', 'Customer Success Manager'),
            ('Layla', 'Collins', '1997-08-15', 'Graphic Designer'),
            ('Jack', 'Stewart', '1989-12-07', 'Network Administrator'),
            ('Aria', 'Sanchez', '1994-04-18', 'Frontend Developer'),
            ('Owen', 'Morris', '1991-06-02', 'Backend Developer'),
            ('Camila', 'Rogers', '1996-07-11', 'Quality Assurance Engineer'),
            ('Wyatt', 'Reed', '1988-05-03', 'IT Support Specialist'),
            ('Nora', 'Cook', '1995-09-22', 'Business Development Rep'),
            ('Ryan', 'Morgan', '1987-11-25', 'Senior Data Scientist')
""")

# %%
con.commit()

# %%
for row in cur.execute("SELECT last_name FROM employees ORDER BY last_name"):
    print(row)
# Out:
# ('Adams',)
# ('Allen',)
# ('Anderson',)
# ('Baker',)
# ('Brown',)
# ('Campbell',)
# ('Carter',)
# ('Clark',)
# ('Collins',)
# ('Cook',)
# ('Davis',)
# ('Edwards',)
# ('Evans',)
# ('Garcia',)
# ('Green',)
# ('Hall',)
# ('Harris',)
# ('Hernandez',)
# ('Jackson',)
# ('Johnson',)
# ('King',)
# ('Lee',)
# ('Lewis',)
# ('Lopez',)
# ('Martin',)
# ('Martinez',)
# ('Miller',)
# ('Mitchell',)
# ('Moore',)
# ('Morgan',)
# ('Morris',)
# ('Nelson',)
# ('Parker',)
# ('Perez',)
# ('Phillips',)
# ('Reed',)
# ('Roberts',)
# ('Rodriguez',)
# ('Rogers',)
# ('Sanchez',)
# ('Scott',)
# ('Stewart',)
# ('Taylor',)
# ('Thomas',)
# ('Thompson',)
# ('Turner',)
# ('Walker',)
# ('White',)
# ('Wilson',)
# ('Wright',)
# ('Young',)

# %% [markdown]
# make a department and salary table here too

# %%
cur.execute("CREATE TABLE")
